# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
data=pd.read_csv('/Users/abhijeetkashyap/Desktop/heart 2.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
import seaborn as sns

# %% [markdown]
# ## distrubtion for numerical values

# %%
sns.displot([data['Age']]) # give overall distrubution of that variable

# %%
sns.displot(data['Age'],kde=True) # for distrubution curve

# %%
sns.displot(data['Age'],kde=True,rug=True,color='blue') # used for density

# %%
sns.set(rc={'figure.figsize':(24,6)})
sns.countplot(x=data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.displot(data['RestingBP'],kde=True,color='blue')

# %%
sns.distplot(data['RestingBP'],kde=True,color='blue')
# Out:
# /Users/abhijeetkashyap/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RestingBP', ylabel='Density'>

# %%
sns.displot(data['Cholesterol'],kde=True,color='blue')

# %%
ct=0
for i in data['Cholesterol']:
    if i==0:
        ct+=1
print(ct)
# Out:
# 172

# %%
sns.distplot(data['FastingBS'],kde=True)
# Out:
# /Users/abhijeetkashyap/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='FastingBS', ylabel='Density'>

# %%
data.groupby('FastingBS').count()
# Out:
#            Age  Sex  ChestPainType  RestingBP  Cholesterol  RestingECG  MaxHR  \
# FastingBS
# 0          704  704            704        704          704         704    704
# 1          214  214            214        214          214         214    214
#
#            ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# FastingBS
# 0                     704      704       704           704
# 1                     214      214       214           214

# %% [markdown]
# ## distrubution of catogerical values

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
data.groupby('Sex').count()
# Out:
#      Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# Sex
# F    193            193        193          193        193         193    193
# M    725            725        725          725        725         725    725
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# Sex
# F               193      193       193           193
# M               725      725       725           725

# %%
data.groupby('Sex').size().plot(kind='pie',autopct='%.0f',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='None'>

# %%
data.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# ## chances for male and feamle

# %%
sns.set(rc={'figure.figsize':(6,6)}) # wrong
sns.countplot(x='HeartDisease',hue='Sex',data=data).

# %% [markdown]
# ## chances for whole population

# %%
data.groupby('HeartDisease').size()
# Out:
# HeartDisease
# 0    410
# 1    508
# dtype: int64

# %%
data.groupby('HeartDisease').size().plot(kind='pie',autopct='%.2f',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # violin plot

# %% [markdown]
# ## chances for male and feamle

# %%
sns.violinplot(y=data['Sex'],x=data['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=data['Age'],x=data['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Age'>

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
sns.violinplot(x=data['HeartDisease'],y=data['Cholesterol'])
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## heat map

# %%
data.corr() # correlation between different column
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## joint plot

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
sns.jointplot(x='Age',y='MaxHR',data=data) # used to show the relation between columns by graphs

# %%
sns.jointplot(x='Age',y='Age',data=data) # 100% related to ecah other

# %%
sns.jointplot(x='HeartDisease',y='Oldpeak',data=data) # no corelation

# %%
sns.jointplot(x='Age',y='MaxHR',data=data,kind='hex')

# %%
sns.jointplot(x='Age',y='MaxHR',data=data,kind='reg')

# %%
sns.jointplot(x='Cholesterol',y='FastingBS',data=data,kind='reg')

# %%
sns.jointplot(x='Age',y='HeartDisease',data=data,kind='reg')

# %%
sns.jointplot(x='HeartDisease',y='Age',data=data,kind='reg')
